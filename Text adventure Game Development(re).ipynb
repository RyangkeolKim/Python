# %%
"""
Created on Fri Oct 22 17:52:46 2021

@author: 
"""

"""
    The Fellowship of the Ring:
    
    A) Introduction:
    This game is based on the movie Grail Lord of the Rings
    (2001). It consists of three stages, and also has defined functions
    for start, win, and lose. 
    Considering people who don't know the contents of the movie, 
    I used the easiest words as possible. Don't believe too much in the movie.
    
    Round 1: Khazad Dum
    Round 2: The two tower
    Round 3: Mordor volcano
    
    B) Known Bugs and/or Errors:
    None.
   
"""
from sys import exit
import random

#########################################################
# Constructing fail and tutorial calling it to start the game
#########################################################
def fail():
    print("The fellowship is failed.")
    exit() # This moves us into fail

print("""
         ___ . .  _                                                                                             
 TAAAP    |  |_| |_                                                                                             
  AAA     |  | | |_                                                                                             
  AAA                                                       TAAAAAA$b.                                          
  AAA     .gAAAAAp.   TAAAAb.    TAAAAAbp.                   BUG    "Tb      T$b      T$P   .gAP^^TAA  ,gP^^TAA 
  AAA    d^       ^b   AA   Tb    AA    "Tb    .s^s. :sssp   AAA     :A; TAAP A^b.     A   dP"     `T :AP    `T
   AA   dP         Tb  AA    A;   AA      Tb  d'   `b A      AAA     :A$;  AA  A `Tp    A  dA           Tbp.   
   AA  :A;         :A; AA    A;   AA      :A; T.   .P A^^    AAA    .dP   AA  A   ^b.  A :A;            "TAAp.  
  AAA  :A;         :A; AA...dP    AA      :A;  `^s^' .A.     AAA...dP"    AA  A    `Tp A :A;     "TAA      "TAb 
  AAA   Tb.       ,dP  AA---Tb    AA      dP ""A""A" "A"A^^  AAAMMTAb     AA  A      ^bA  TA       TA ;      AA;
  AAA    Tp._   _,gP   AA   `Tb.  AA    ,dP    A  A...A A..  AAA   TAb    :A  A       `A   Tb.     :A T.    ,dP 
  AAA;    "^AAAAA^"   dAA     `T. dAAAA$P^     A  AMMA AMM, AAA    TAb  dAAbdAb      dAb   "^TbsssP" 'TAbgdAP  
  AAAb.____.dP                                 A .A. .A.Ass,dAAAb.   TAb.                                       
.dAAAAAAAAAAP                                                        `TAb.""")
print("")
name_1 = input(prompt="""You are the 10th colleague of the ring fellowship.
\nWould you tell me your name?""")
# Start of tutorial
print(f"""                                   
   _______________________-------------------------------------------`
 /:--__                                                              |
||< > |                                   ___________________________/
| \__/_________________-------------------                         |
|                                                                  |
 |                       THE LORD OF THE RINGS                     |
 |                                                                  |
 |       {name_1} have joined the Ring Fellowship.                  |
  |      You have to survive numerous orcs and Traps,               |
  |      overcome the temptation of the ring,                        |
  |      and move the ring to the Mordor volcano to destroy it.      |
  |      In the process, your wisdom, courage,                       |
   |     and your judgment will determine                             |
   |     the success and failure of the fellowship.                   |
   |     Please make a careful judgment!                              |
  |                                              ____________________ __|_
  |  ___________________-------------------------                        |
  |/`--_                                                                 |
  ||[ ]||                                            ___________________/
   \===/___________________--------------------------""")
print("")
input("                     <   Press enter to continue   >\n")
print("=========================== STAGE 1 ===========================")
print("")
print(f"""To go to Mordor, we have no choice but to enter Khazad Dum, 
the capital of ancient dwarves where Balrog, the ancient devil, was asleep.""")
input("                     <   Press enter to continue   >\n")
print("""
                                 _,-----------._        
                             _,-'_,-----------._`-._    
                            ,'_,-'  ___________  `-._`.
                         ,','  _,-'___________`-._  `.`.
                        ,','  ,'_,-'     .     `-._`.  `.`.
                       /,'  ,','        >|<        `.`.  `.`.
                      //  ,','      ><  ,^.  ><      `.`.  ``. 
                     //  /,'      ><   / | _   ><      `.`.  ``.
                    //  //      ><    _/_^/_/    ><     `.`.  ``.
                   ;;  ;;              `---'              ::  ::
                   ||  ||              (____              ||  ||
                  _||__||_            ,'----.            _||__||_
                 (o.____.o)____        `---'        ____(o.____.o)
                   |    | /,--.)                   (,--._ |    |
                   |    |((  -`___               ___`   ))|    |
                   |    | __,'',  `.           .'  .``.// |    |
                   |    |  // (___,'.         .'.___) __  |    |
                  /|    | ;;))  ____) .     . (____  ((__ |    |_
                  _|.__ | ||/ .'.--._/       `/,--.`. _;: | __,|;
                   |`-,`;.| :/ /,'  `)-'   `-('  `._ _: |.;',-'|
                   |   `..  ' / ___.'         `.__/ _ `  ,.'   |
                   |    |,_  /,                     ,_  /,|    |
                   |    ||: : )          .          ( : :||    |
                  /|    |:; |/  .      ./|_,      ,  _| :;|    |_
                  _|.__ |/  :  ,/-    <--:-->    ,_.  ;  _| __,|;
                   |`-.``:   `'/-.     '_|/`     ,-_`;   ;'',-'|
                   |   `..   ,' `'       '       `  `.   ,.'   |
                   |    ||  :                         :  ||    |
                   |    ||  |                         |  ||    |
                   |    ||  |                         |  ||    |
                   |    |'  |            _            |  `|    |
                   |    |   |          '|))           |   |    |
                   ;____:   `._        `'           _,'   ;____:
                  |______|     ____________________/     |______|
                  |______|_______________________________|______|\n""")
print("""To enter there, You have to open Durin door, 
which opens only when you shout out an elf language called 'FRIEND'.\n""")
print("""              <Hint>          
Gray Wizard: Same as the name of a fruit in the human world..
      Melbourne? Melatonin? Melodrama?...Mel...\n
      Enter the elf word 'Friend'""")
code = input(">" )
code = code.lower()
if "melon" in code or "melon!" in code or "Melon" in code or "Melon!" in code or "MELON" in code:
    print("The door is open! Everyone, come on in!!\n")
    input("                     <   Press enter to continue   >\n")
    balrog_scene()
else:
    print("""Orcs:"You're an intruder!"
You've been killed by evil groups.""")
    fail()     
    # This moves us into fail

#########################################################
# Adding balrog_scene and linking it to tutorial
#########################################################
def balrog_scene():
    print("""You found a shiny ancient sword <string> and put it in a bag.
    Suddenly, the soil dust there stimulated your nose and sneezed with a tremendous sound.
The sound was enough to wake up the ancient devil, and because of your carelessness, 
the fellowship faced a tremendous crisis.""")
    print("""
    Fellowship met Balrog. What's your behavior?
    1) We're going to fight! 
    2) Let's run away!""")
choice = input(">  \n") 
# Start of nested conditional
if "2" in choice or "run" in choice or "run away" in choice:
    print("""\nThe fellowship successfully escaped the Khazad-Dum. 
        However,Fellowship lost the gray wizard, who was the team's leader.""")
    input("<Press enter to continue>\n")
    the_towers() 
    # This moves us into the_woers()
elif "1" in choice or "fight" in choice or "one" in choice:
    print("""\nThe fellowship fought hard against Balrog,
    but they couldn't beat Balrog on Balrog's home ground and the ring's fellowship failed.\n""")
    fail() 
    # This moves us into fail
else:
    print("Invalid command. Please try again.")
    input("<Press enter to continue>\n")
    balrog_scene() 
    # This moves us into barlog_scene()
    # End of nested conditional
#############################################################################
####Due to running out of time, it was replaced with a small mini-game, 
####and the while code was used.
#############################################################################   
def the_towers():
    print("=========================== STAGE 2 ===========================")
    input("                 <   Press enter to continue   >\n")
    print("""Fellowship that became nine.
Seven of them leave to help Minastirith defend under oak airstrikes, 
and only You and the Ring-bearer leave for the Mordor volcano.
However, However, we, who don't know the way, 
want to stop by the white wizard's tower and get advice..\n""")
    input("                 <   Press enter to continue   >\n")
    print("""
    .       ..       .
    |.      ||      /|
    | .     ||     / |
    |  '    ||    /  |
    |  :'___JL___/   |
    |  :|AAXLJ: :|   |
    '. :|AAA||: X|  /'
      ':|AAA||:XA| /
       |==========|
        |AAAXXX;;|
        |AAXn:: :|
        |AAXU:: :|
        |AAXX:: n|
        |AAXX:: U|
        |AAXn:: :|
        |AAXU:: :|
        |AAXX:: n|
        |AAXX:: U|
        |AAXn:: :|
        |AAXU:: :|
        |./ T \.:|
        || o|o |:|
        ||  |  |:|
      .============.
     .==============.
    .================.
White Wizard "If you answer my question correctly,
I will help you accompany a guide named Gollum to your party!\n
only say the answer in numbers of 1, 2, 3." """)
          
    question_list = ['What’s the most detail-oriented ocean?',
                     'What would the Terminator be called in his retirement?',
                     'Which state has the most streets?',
                     'Why did the coach go to the bank?']
    questions = 3
    # Start of nested conditional
    while questions > 0:
        question = random.choice(question_list)
        print(question)
        print("")
        
        if question == question_list[0]:
            print("1) The Pacific")
            print("2) The Atlantic")
            print("3) The Arctic")
            
            quest = input("> \n")
            
            if quest == '1':
                print("That's pretty good. That's the answer.\n")
                questions -=1
            
            else:
                print("You were kicked out because you didn't understand the wizard's joke.")
                fail() 
                # This moves us into fail
                      # End of nested Q0
        elif question == question_list[1]:
            print("1) Arnold Alois Schwarzenegger?")
            print("2) I don't know....")
            print("3) The Exterminator.")

            quest = input("> \n")
            
            if quest == '3':
                print("Thanks for letting me know. It's kind of lonely guarding this bridge all the time.\n")
                questions -=1
            
            else:
                print("You were kicked out because you didn't understand the wizard's joke.")
                fail() 
                # This moves us into fail
            # End of nested Q1
        elif question == question_list[2]:
            print("1) Commonwealth of Massachusetts")
            print("2) Rhode Island")
            print("3) State of California")
            
            quest = input("> \n")
            
            if quest == '2':
                print("That's pretty good. That's the answer.\n")
                questions -=1
            
            else:
                print("You were kicked out because you didn't understand the wizard's joke.")
                fail() 
                # This moves us into fail
                        # End of nested Q2
        elif question == question_list[3]:
            print("1) To make a new card")
            print("2) To invest in Bitcoin")
            print("3) To get his quarterback")
            
            quest = input("> \n")
            
            if quest == '3':
                print("That's pretty good. That's the answer.\n")
                questions -=1
            
            else:
                print("You were kicked out because you didn't understand the wizard's joke.")
                fail() 
                # This moves us into fail

                break            
                # End of nested Q3
            
    print("I'll let you guys go as promised!\n")
    input("<Press enter to continue>\n")
    Mordor_volcano() 
    # This moves us into Mordor_volacno()

#############################################################################
####Adding the_tower and linking it to Mordor_volcano
#############################################################################
def Mordor_volcano():
    print("=========================== STAGE 3 ===========================")
    input("                 <   Press enter to continue   >\n")
    print(""" You, the Ring-bearer, and Gollum arrived at the top of Mordor Volcano. 
If the ring carrier throws the absolute ring into the lava of the volcano, 
the fellowship will save the world.""")
    print(""""However, the bearer of the ring becomes a slave of the ring, 
          killing Gollum and trying to kill you.\n
          What's your behavior?""")
    
    print("1) I'll kill you and destroy the ring instead of you!!")
    print("2) I don't want to die. Run away!")
    
    fight = input("> \n")
    
    if '1' in fight or 'kill' in fight or 'destroy' in fight or 'destroy the ring' in fight:
        print("""A tough battle took place, 
        but thanks to the treasure you brought from Khazad Dum, 
        you were able to win.""")
        input("<Press enter to continue>\n")
        Ending() 
        # This moves us into Ending
    
    elif '2' in fight or 'run' in fight or """don't want ot die""" in fight:
        print("""Your selfish mind and weakness have destroyed the world. 
              All your city and friends are dead and you are imprisoned and tortured every day.""")
        fail() 
        # This moves us into fail

#############################################################################
####Adding Mordor_volcano and linking it to Ending
#############################################################################
def Ending():
    print(""" This is the last one. 
    All you have to do is become a carrier of a new ring and throw the ring into the lava. 
    However, the absolute ring begins to talk to you.\n
Ring:I can give you everything you want! Countless money, your own army, honor, lover..
Don't destroy me, but rule the world with me!\n""")
    print()
    print("1) Become the new owner.")
    print("2) Destroy the ring ")
    
    behavior = input("> \n")
    
    if '1' in behavior or 'Become' in behavior or 'new' in behavior or 'owner' in behavior:
        print("Good! I actually wanted strength, too! If I use this power well, wouldn't everyone be happy?\n")
        input("<Press enter to continue>\n")
        print("You failed to overcome the last temptation of the ring and fell.")
        fail() 
        # This moves us into fail
    
    elif '2' in behavior or 'destroy' in behavior or 'destroy the ring' in behavior:
        print("""I'm no longer fooled by your false deception. 
              You will destroy me. Before that, I will get rid of you and bring back peace to the world.""")
        finish() 
        # This moves us into finish
#############################################################################
####Adding Ending and linking it to finish
#############################################################################        
def finish():
    input("<Press enter to continue>\n")
    print("You destroyed the ring safely, and all the groups of evil died. The ring's fellwoship was successful.")
    exit()
# Out:
#          ___ . .  _
#  TAAAP    |  |_| |_
#   AAA     |  | | |_
#   AAA                                                       TAAAAAA$b.
#   AAA     .gAAAAAp.   TAAAAb.    TAAAAAbp.                   BUG    "Tb      T$b      T$P   .gAP^^TAA  ,gP^^TAA
#   AAA    d^       ^b   AA   Tb    AA    "Tb    .s^s. :sssp   AAA     :A; TAAP A^b.     A   dP"     `T :AP    `T
#    AA   dP         Tb  AA    A;   AA      Tb  d'   `b A      AAA     :A$;  AA  A `Tp    A  dA           Tbp.
#    AA  :A;         :A; AA    A;   AA      :A; T.   .P A^^    AAA    .dP   AA  A   ^b.  A :A;            "TAAp.
#   AAA  :A;         :A; AA...dP    AA      :A;  `^s^' .A.     AAA...dP"    AA  A    `Tp A :A;     "TAA      "TAb
#   AAA   Tb.       ,dP  AA---Tb    AA      dP ""A""A" "A"A^^  AAAMMTAb     AA  A      ^bA  TA       TA ;      AA;
#   AAA    Tp._   _,gP   AA   `Tb.  AA    ,dP    A  A...A A..  AAA   TAb    :A  A       `A   Tb.     :A T.    ,dP
# ...
